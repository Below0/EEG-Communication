# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %matplotlib inline

plt.style.use('ggplot')

mpl.rcParams['axes.unicode_minus'] = False

train = pd.read_csv("RawValue.csv")
#train2 = sns.load_dataset("train")
train.rename(columns = {"Unnamed: 0" : "time"}, inplace = True)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15864 entries, 0 to 15863
# Data columns (total 3 columns):
# time        15864 non-null int64
# Time        15864 non-null object
# RawValue    15864 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 309.9+ KB

# %%
train.isnull().sum()
# Out:
# time        0
# Time        0
# RawValue    0
# dtype: int64

# %%
import missingno as msno
msno.matrix(train, figsize=(3,5))

# %%
"""figure, ((ax1,ax2)) = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(28,18)"""

ax = sns.lineplot(x="time", y="RawValue", data=train)
#figure.set_size_inches(28,18)
